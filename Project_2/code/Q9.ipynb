# %%
library(igraph)
# install.packages("ggplot2")
library(ggplot2)
g <- read.graph('facebook_combined.txt', format = 'edgelist', directed = FALSE)

# %% [markdown]
# ## Problem 9

# %%
sub_g1 = induced.subgraph(g, c(1, neighbors(g,1)))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)

sub_g1 = induced.subgraph(g, c(108, neighbors(g,108)))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)

sub_g1 = induced.subgraph(g, c(349, neighbors(g,349)))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)

sub_g1 = induced.subgraph(g, c(484, neighbors(g,484)))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)

sub_g1 = induced.subgraph(g, c(1087, neighbors(g,1087)))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
