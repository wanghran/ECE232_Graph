# %%
library(igraph)
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
g <- read_graph("../facebook_combined.txt", format="edgelist", directed=FALSE)

# %%
counter <- 0
deg <- seq_len(0)
for (i in 1:vcount(g)){
    v = neighbors(g, i)
    if (length(v) >= 201) {
        counter <- counter+1
        deg <- c(deg, length(v))
    }
}
print(counter)
print(mean(deg))
# Out:
# [1] 40
# [1] 279.375

# %%
V(g)$id <- seq(1, 4039)
g1 <- add_vertices(g, 1, id=4040)
for
# Out:
# Error in which(id = 4040): unused argument (id = 4040)
# Traceback:
#
# 1. V(g1)[which(id = 4040)]
# 2. `[.igraph.vs`(V(g1), which(id = 4040))
# 3. lazy_eval(args, data = c(attrs, .nei = .nei, nei = nei, .innei = .innei,
#  .     innei = innei, .outnei = .outnei, outnei = outnei, adj = adj,
#  .     .inc = .inc, inc = inc, .from = .from, from = from, .to = .to,
#  .     to = to))
# 4. lapply(x, lazy_eval, data = data)
# 5. FUN(X[[i]], ...)
# 6. eval(x$expr, data, x$env)
# 7. eval(x$expr, data, x$env)

# %%
sub_g1 = induced.subgraph(g, neighbors(g,1))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g1)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g1))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = edge.betweenness.community(sub_g1)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g1)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g1,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
# Out:
# [1] 0.4418533
# [1] 0.4161461
# Plot with title “”
# [1] 0.4180077
# Plot with title “”
# Plot with title “”

# %%
sub_g2 = induced.subgraph(g, neighbors(g,108))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g2)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g2))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g2,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = cluster_edge_betweenness(sub_g2)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g2,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g2)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g2,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
# Out:
# [1] 0.4581271

# %%
sub_g3 = induced.subgraph(g, neighbors(g,349))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g3)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g3))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g3,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = cluster_edge_betweenness(sub_g3)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g3,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g3)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g3,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
# Out:
# [1] 0.4581271

# %%
sub_g4 = induced.subgraph(g, neighbors(g,484))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g4)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g4))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g4,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = cluster_edge_betweenness(sub_g4)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g4,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g4)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g4,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)

# %%
sub_g5 = induced.subgraph(g, neighbors(g,1087))
#fastgreedy
fastgreedy = fastgreedy.community(sub_g5)
color_vector = fastgreedy$membership+1
vertex_vector = rep(4,vcount(sub_g5))
vertex_vector[1]=6
print(modularity(fastgreedy))
plot(fastgreedy,sub_g5,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#edge-betweenness
edgebetween = cluster_edge_betweenness(sub_g5)
color_vector = edgebetween$membership+1
print(modularity(edgebetween))
plot(sub_g5,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
#Infomap
infomap = infomap.community(sub_g5)
color_vector = infomap$membership+1
print(modularity(infomap))
plot(sub_g5,vertex.color=color_vector,vertex.label=NA,vertex.size=vertex_vector)
