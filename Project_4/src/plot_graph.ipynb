# %%
library('igraph')
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
g <- read_graph('../output/edge_list.txt', format='ncol')

# %%
plot(degree.distribution(g, mode='in'),main="In-Degree distribution of the actor/actress network",xlab="In-degree number",ylab="Frequency")
# Out:
# Plot with title “In-Degree distribution of the actor/actress network”

# %%
g
