# %%
library('igraph')
# Out:
# Attaching package: ‘igraph’
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
g <- read_graph('../output/edge_list.txt', format='ncol')

# %%
plot(degree.distribution(g),main="Degree distribution of the actor/actress network",xlab="Degree",ylab="Frequency", type="h")
# Out:
# Plot with title “Degree distribution of the actor/actress network”

# %%
g
