# %%
library('igraph')

# %%
g <- read_graph('../output/edge_list.txt', format='ncol')

# %%
plot(degree.distribution(g, mode='in'),main="Degree distribution of the actor/actress network",xlab="In-degree",ylab="Frequency", type="h")
# Out:
# Plot with title “Degree distribution of the actor/actress network”

# %%
g
